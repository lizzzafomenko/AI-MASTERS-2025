# %% [markdown]
# ## Домашнее задание 23

# %% [markdown]
# ### Задача 1
#
# Реализуйте структуру данных Union-find (она же система непересекающихся множеств). Протестируйте ее на графах с лекции. Добавьте оптимизацию со сжатием путей

# %%
# YOUR CODE HERE

# %% [markdown]
# ### Задача 2
#
# Реализуйте алгоритм Краскала на основе системы непересекающихся множеств. Визуализируйте результаты его работы с помощью networkx

# %%
# YOUR CODE HERE

# %% [markdown]
# ### Задача 3
#
# Реализуйте генерацию лабиринтов на основе построения MST в графе со случайными весами

# %%
# YOUR CODE HERE
